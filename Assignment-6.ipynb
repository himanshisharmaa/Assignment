# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Take this monstrosity as the DataFrame to use in the following puzzles:
# df = pd.DataFrame({'From_To': ['LoNDon_paris', 'MAdrid_miLAN', 'londON_StockhOlm', 'Budapest_PaRis', 'Brussels_londOn'],
#
# 'FlightNumber': [10045, np.nan, 10065, np.nan, 10085],
#
# 'RecentDelays': [[23, 47], [], [24, 43, 87], [13], [67, 32]],
#
# 'Airline': ['KLM(!)', ' (12)', '(British Airways. )', '12. Air France', '"Swiss Air"']})

# %%
df=pd.DataFrame({'From_to':['LoNDon_paris','MAdrid_miLAN','londON_StockhOlm','Budapest_PaRis','Brussels_londOn'],
                'FlightNumber':[10045,np.nan,10065,np.nan,10085],
                'RecentDelays':[[23,47],[],[24,43,87],[13],[67,32]],
                'Airline':['KLM(!)','<Air France>(12)','(British Airways.)','12.Air France','''Swiss Air''']})

# %%
df
# Out:
#             From_to  FlightNumber  RecentDelays             Airline
# 0      LoNDon_paris       10045.0      [23, 47]              KLM(!)
# 1      MAdrid_miLAN           NaN            []    <Air France>(12)
# 2  londON_StockhOlm       10065.0  [24, 43, 87]  (British Airways.)
# 3    Budapest_PaRis           NaN          [13]       12.Air France
# 4   Brussels_londOn       10085.0      [67, 32]           Swiss Air

# %% [markdown]
# ### Some values in the the FlightNumber column are missing. These numbers are meant to increase by 10 with each row so 10055 and 10075 need to be put in place. Fill in these missing numbers and make the column an integer column (instead of a float column).

# %%
df['FlightNumber'].fillna(value=df['FlightNumber'][0]+10,limit=1,inplace=True)
df['FlightNumber'].fillna(value=df['FlightNumber'][2]+10,limit=1,inplace=True)

# %%
df
# Out:
#             From_to  FlightNumber  RecentDelays             Airline
# 0      LoNDon_paris       10045.0      [23, 47]              KLM(!)
# 1      MAdrid_miLAN       10055.0            []    <Air France>(12)
# 2  londON_StockhOlm       10065.0  [24, 43, 87]  (British Airways.)
# 3    Budapest_PaRis       10075.0          [13]       12.Air France
# 4   Brussels_londOn       10085.0      [67, 32]           Swiss Air

# %%
df['FlightNumber'].astype(np.int64)
# Out:
# 0    10045
# 1    10055
# 2    10065
# 3    10075
# 4    10085
# Name: FlightNumber, dtype: int64

# %% [markdown]
# ### The FromTo column would be better as two separate columns! Split each string on the underscore delimiter to give a new temporary DataFrame with the correct values. Assign the correct column names to this temporary DataFrame.

# %%
fromto=df['From_to'].str.split('_',expand=True)

# %%
fromto
# Out:
#           0          1
# 0    LoNDon      paris
# 1    MAdrid      miLAN
# 2    londON  StockhOlm
# 3  Budapest      PaRis
# 4  Brussels     londOn

# %%
fromto.columns=['From','To']

# %%
fromto
# Out:
#        From         To
# 0    LoNDon      paris
# 1    MAdrid      miLAN
# 2    londON  StockhOlm
# 3  Budapest      PaRis
# 4  Brussels     londOn

# %%
df2=pd.concat([df,fromto],axis=1)
df2
# Out:
#             From_to  FlightNumber  RecentDelays             Airline      From  \
# 0      LoNDon_paris       10045.0      [23, 47]              KLM(!)    LoNDon
# 1      MAdrid_miLAN       10055.0            []    <Air France>(12)    MAdrid
# 2  londON_StockhOlm       10065.0  [24, 43, 87]  (British Airways.)    londON
# 3    Budapest_PaRis       10075.0          [13]       12.Air France  Budapest
# 4   Brussels_londOn       10085.0      [67, 32]           Swiss Air  Brussels
#
#           To
# 0      paris
# 1      miLAN
# 2  StockhOlm
# 3      PaRis
# 4     londOn

# %% [markdown]
# ### Delete the From_To column from df and attach the temporary DataFrame from the previous questions.

# %%
df2.drop(df2[['From_to']],axis=1,inplace=True)

# %%
df2
# Out:
#    FlightNumber  RecentDelays             Airline      From         To
# 0       10045.0      [23, 47]              KLM(!)    London      Paris
# 1       10055.0            []    <Air France>(12)    Madrid      Milan
# 2       10065.0  [24, 43, 87]  (British Airways.)    London  Stockholm
# 3       10075.0          [13]       12.Air France  Budapest      Paris
# 4       10085.0      [67, 32]           Swiss Air  Brussels     London

# %% [markdown]
# ### Notice how the capitalisation of the city names is all mixed up in this temporary DataFrame. Standardise the strings so that only the first letter is uppercase (e.g. "londON" should become "London".)

# %%
df2['From']=df2['From'].str.capitalize()
df2['To']=df2['To'].str.capitalize()
df2
# Out:
#    FlightNumber  RecentDelays             Airline      From         To
# 0       10045.0      [23, 47]              KLM(!)    London      Paris
# 1       10055.0            []    <Air France>(12)    Madrid      Milan
# 2       10065.0  [24, 43, 87]  (British Airways.)    London  Stockholm
# 3       10075.0          [13]       12.Air France  Budapest      Paris
# 4       10085.0      [67, 32]           Swiss Air  Brussels     London

# %% [markdown]
# ### In the RecentDelays column, the values have been entered into the DataFrame as a list. We would like each first value in its own column, each second value in its own column, and so on. If there isn't an Nth value, the value should be NaN.
#
# ### Expand the Series of lists into a DataFrame named delays, rename the columns delay_1, delay_2, etc. and replace the unwanted RecentDelays column in df with delays.

# %%
delay=pd.DataFrame(df2['RecentDelays'].to_list(),columns=['delay1','delay2','delay3'])
delay
# Out:
#    delay1  delay2  delay3
# 0    23.0    47.0     NaN
# 1     NaN     NaN     NaN
# 2    24.0    43.0    87.0
# 3    13.0     NaN     NaN
# 4    67.0    32.0     NaN

# %%
df3=pd.concat([df2,delay],axis=1)
df3
# Out:
#    FlightNumber  RecentDelays             Airline      From         To  \
# 0       10045.0      [23, 47]              KLM(!)    London      Paris
# 1       10055.0            []    <Air France>(12)    Madrid      Milan
# 2       10065.0  [24, 43, 87]  (British Airways.)    London  Stockholm
# 3       10075.0          [13]       12.Air France  Budapest      Paris
# 4       10085.0      [67, 32]           Swiss Air  Brussels     London
#
#    delay1  delay2  delay3
# 0    23.0    47.0     NaN
# 1     NaN     NaN     NaN
# 2    24.0    43.0    87.0
# 3    13.0     NaN     NaN
# 4    67.0    32.0     NaN

# %%
df3.drop(df3[['RecentDelays']],axis=1)
# Out:
#    FlightNumber             Airline      From         To  delay1  delay2  \
# 0       10045.0              KLM(!)    London      Paris    23.0    47.0
# 1       10055.0    <Air France>(12)    Madrid      Milan     NaN     NaN
# 2       10065.0  (British Airways.)    London  Stockholm    24.0    43.0
# 3       10075.0       12.Air France  Budapest      Paris    13.0     NaN
# 4       10085.0           Swiss Air  Brussels     London    67.0    32.0
#
#    delay3
# 0     NaN
# 1     NaN
# 2    87.0
# 3     NaN
# 4     NaN

# %%
df3=df3[['From','To','FlightNumber','delay1','delay2','delay3','Airline']]
df3
# Out:
#        From         To  FlightNumber  delay1  delay2  delay3  \
# 0    London      Paris       10045.0    23.0    47.0     NaN
# 1    Madrid      Milan       10055.0     NaN     NaN     NaN
# 2    London  Stockholm       10065.0    24.0    43.0    87.0
# 3  Budapest      Paris       10075.0    13.0     NaN     NaN
# 4  Brussels     London       10085.0    67.0    32.0     NaN
#
#               Airline
# 0              KLM(!)
# 1    <Air France>(12)
# 2  (British Airways.)
# 3       12.Air France
# 4           Swiss Air
